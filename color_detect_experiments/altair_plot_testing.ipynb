# %%
import altair as alt 
import pandas as pd

tidy_df = pd.read_csv('/home/lmeyers/ReID_complete/auto_eval_models_color_detect/evaluations_epoch_800.csv')

imgs_df = tidy_df[tidy_df['num_ids']==63]
imgs_df = imgs_df[imgs_df['evaluation_metric']=='percent_correct_id']

imgs_df
# Out:
#     Unnamed: 0                                            run_str  num_ids  \
# 11         240  summer_bee_dataset_open_train_bee_64_ids_batch...       63
# 12         254  summer_bee_dataset_open_train_bee_64_ids_batch...       63
# 13         275  summer_bee_dataset_open_train_bee_64_ids_batch...       63
# 14         301  summer_bee_dataset_open_train_bee_64_ids_batch...       63
# 15         343  summer_bee_dataset_open_train_bee_64_ids_batch...       63
# 16         382  summer_bee_dataset_open_train_bee_64_ids_batch...       63
#
#     num_images_per_id  total_training_images  batch_size  num_epochs    steps  \
# 11                 64                   3868          64         800  49587.0
# 12                 32                   2002          64         800  26400.0
# 13                 16                   1008          64         800  13600.0
# 14                  8                    504          64         800   7200.0
# ...

# %%
import numpy as np

maybe_chart2 = alt.Chart(imgs_df).mark_point(filled=True).encode(
x=alt.X('num_images_per_id', sort=['2','4','8','16', '32','64', 'max'], title='Number of Images'),
    y=alt.Y('Percent', title= 'Top-1 Accuracy',scale=alt.Scale(domain=[0,1], bins=list(np.arange(0,1.1,0.1)))),
    opacity=alt.value(1.0),
    #color=alt.Color('type_of_reference'),
    #shape= alt.Shape('type_of_reference', legend=alt.Legend(orient='top-left', title='Set used for Reference split')),
    size=alt.value(120)
).properties(title='64 IDs varying images', width=300,height=200)


#"""
maybe_chart = alt.Chart(imgs_df).mark_line().encode(
 x=alt.X('num_images_per_id', sort=['2','4','8','16', '32','64', 'max'], title='Number of Images'),
    y=alt.Y('Percent', title= 'Top-1 Accuracy',scale=alt.Scale(domain=[0,1], bins=list(np.arange(0,1.1,0.1)))),
    opacity=alt.value(0.8),
    #color=alt.Color('type_of_reference', legend=None),
  )
    


alt.layer(maybe_chart2, maybe_chart).resolve_scale(color='independent',shape='independent' )
# Out:
# /home/lmeyers/anaconda3/envs/mlenv/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /home/lmeyers/anaconda3/envs/mlenv/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)

# %%
ids_df = tidy_df[tidy_df['num_images_per_id']==64]
ids_df = ids_df[ids_df['evaluation_metric']=='percent_correct_id']

ids_df
# Out:
#     Unnamed: 0                                            run_str  num_ids  \
# 11         240  summer_bee_dataset_open_train_bee_64_ids_batch...       63
# 17         392  summer_bee_dataset_open_train_bee_32_ids_permu...       32
# 18         411  summer_bee_dataset_open_train_bee_24_ids_monoc...       24
# 19         423  summer_bee_dataset_open_train_bee_16_ids_four_...       16
# 20         455  summer_bee_dataset_open_train_bee_8_ids_double...        8
# 21         478  summer_bee_dataset_open_train_bee_4_ids_batch1...        4
#
#     num_images_per_id  total_training_images  batch_size  num_epochs    steps  \
# 11                 64                   3868          64         800  49587.0
# 17                 64                   2011          64         800  26400.0
# 18                 64                   1512          64         800  20000.0
# 19                 64                   1024          64         800  13600.0
# ...

# %%
chart_dif_split = alt.Chart(ids_df).mark_point(filled=True).encode(
x=alt.X('num_ids', sort=[ ' 8  IDs',' 16  IDs', ' 24  IDs', ' 32  IDs', ' 64  IDs'], title='Number of IDs in training'),
    y=alt.Y('Percent', scale=alt.Scale(domain=[0,1],bins= list(np.arange(0,1.1,0.1)))),
    opacity=alt.value(1.0),
    #color=alt.Color('type_of_reference'),
     #shape= alt.Shape('type_of_reference', legend=alt.Legend(orient='top-left', title='Set used for Reference split')),
    size= alt.value(120)
).properties(title='64 images per different split', width=300,height=200)


chart_dif_split2= alt.Chart(ids_df).mark_line().encode(
x=alt.X('num_ids', sort=[ ' 8  IDs',' 16  IDs', ' 24  IDs', ' 32  IDs', ' 64  IDs'], title='Number of IDs in training'),
    y=alt.Y('Percent',title= 'Top-1 Accuracy', scale=alt.Scale(domain=[0,1], bins= list(np.arange(0,1.1,0.1)))),
    opacity=alt.value(1.0),
    #color=alt.Color('type_of_reference', legend=None))
)


alt.layer(chart_dif_split2, chart_dif_split).resolve_scale(color='independent',shape='independent' )
# Out:
# /home/lmeyers/anaconda3/envs/mlenv/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /home/lmeyers/anaconda3/envs/mlenv/lib/python3.9/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)
